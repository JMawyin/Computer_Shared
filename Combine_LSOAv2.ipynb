# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gc
from scipy import ndimage

# %%
geojson_path = "/Users/josemawyin/Library/Mobile Documents/com~apple~CloudDocs/Data Science Masters /698/Intro Work/lsoa.geojson"
world = gpd.read_file(geojson_path)
world=world.rename(columns = {'LSOA11CD':'LSOA_Code'})
world=world.sort_values('LSOA_Code')
###
#lsoa_centroid_path = "/Users/josemawyin/Library/Mobile Documents/com~apple~CloudDocs/Data Science Masters /698/Data/Output_Areas__December_2011__Population_Weighted_Centroids-shp/Output_Areas__December_2011__Population_Weighted_Centroids.shp"
lsoa_centroid_path = "/Users/josemawyin/Library/Mobile Documents/com~apple~CloudDocs/Data Science Masters /698/Data/LSOA_Dec_2011_Population_Weighted_Centroids-shp/Lower_Layer_Super_Output_Areas__December_2011__Population_Weighted_Centroids.shp"
lsoa_centroid = gpd.read_file(lsoa_centroid_path)
lsoa_centroid=lsoa_centroid.rename(columns = {'lsoa11cd':'LSOA_Code'})
lsoa_centroid=lsoa_centroid.rename(columns = {'lsoa11nm':'LSOA11NMW'})
lsoa_centroid=lsoa_centroid.sort_values('LSOA_Code')
lsoa_centroid=lsoa_centroid.drop(columns=['objectid'])
###
demand_2018_loc = "/Users/josemawyin/Library/Mobile Documents/com~apple~CloudDocs/Downloads/LSOA_DOM_ELEC_csv/LSOA_ELEC_2018.csv"
demand_2018 = pd.read_csv(demand_2018_loc)
demand_2018=demand_2018.rename(columns = {'LSOACode':'LSOA_Code'})
demand_2018=demand_2018.sort_values('LSOA_Code')
###
installations_loc = "/Users/josemawyin/Library/Mobile Documents/com~apple~CloudDocs/Data Science Masters /698/Intro Work/LSOA_installation.csv"
installations = pd.read_csv(installations_loc)

# %%
installations
# Out:
#        Extension (Y/N) PostCode    Technology  Installed capacity  \
# 0                    N     TR11  Photovoltaic                2.88
# 1                    N      TA4  Photovoltaic                2.88
# 2                    N      NW7  Photovoltaic                3.87
# 3                    N      S20  Photovoltaic                3.33
# 4                    N     BA22  Photovoltaic                1.98
# ...                ...      ...           ...                 ...
# 858042               N     DE21  Photovoltaic                3.15
# 858043               N     AB21  Photovoltaic                1.08
# 858044               N     SA37  Photovoltaic                2.24
# 858045               N     LL71  Photovoltaic                3.92
# 858046               N     RH13  Photovoltaic                0.50
#
#         Declared net capacity     Application date Commissioning date  \
# 0                        2.88  2010-04-07 00:00:00         2010-03-24
# 1                        2.88  2010-04-07 00:00:00         2010-03-19
# 2                        3.87  2010-04-07 00:00:00         2010-03-25
# 3                        3.33  2010-04-07 00:00:00         2010-04-07
# 4                        1.98  2010-04-07 00:00:00         2009-07-29
# ...                       ...                  ...                ...
# 858042                   3.00  2019-11-08 00:00:00         2018-06-16
# 858043                   1.08  2019-11-17 00:00:00         2017-08-11
# 858044                   2.00  2019-12-14 00:00:00         2017-12-14
# 858045                   3.92  2019-12-15 00:00:00         2018-11-15
# 858046                   0.50  2019-12-19 00:00:00         2018-10-19
#
#         MCS issue date             Export status      TariffCode  ...  \
# 0                  NaN           Export (Deemed)     PV-R/0-4/01  ...
# 1                  NaN           Export (Deemed)     PV-R/0-4/01  ...
# 2                  NaN           Export (Deemed)     PV-R/0-4/01  ...
# 3                  NaN           Export (Deemed)     PV-R/0-4/01  ...
# 4                  NaN  Export (Standard Tariff)     PV-R/0-4/01  ...
# ...                ...                       ...             ...  ...
# 858042             NaN           Export (Deemed)  PV-R/0-4/09H-1  ...
# 858043             NaN           Export (Deemed)  PV-N/0-4/08H-3  ...
# 858044             NaN           Export (Deemed)  PV-N/0-4/08H-3  ...
# 858045             NaN           Export (Deemed)  PV-R/0-4/09H-3  ...
# 858046             NaN           Export (Deemed)  PV-N/0-4/09L-3  ...
#
#        Installation Type Installation Country  Government Office Region  \
# 0               Domestic              England                South West
# 1               Domestic              England                South West
# 2               Domestic              England                    London
# 3               Domestic              England  Yorkshire and The Humber
# 4               Domestic              England                South West
# ...                  ...                  ...                       ...
# 858042          Domestic              England             East Midlands
# 858043          Domestic             Scotland                  Scotland
# 858044          Domestic                Wales                     Wales
# 858045          Domestic                Wales                     Wales
# 858046          Domestic              England                South East
#
#                   Local Authority           Constituency Accreditation Route  \
# 0                        Cornwall     Truro and Falmouth                 MCS
# 1       Somerset West and Taunton          Taunton Deane                 MCS
# 2                          Barnet                 Hendon                 MCS
# 3                       Sheffield   Sheffield South East                 MCS
# 4                  South Somerset                 Yeovil                 MCS
# ...                           ...                    ...                 ...
# 858042                      Derby            Derby North                 MCS
# 858043              Aberdeen City                 Gordon                 MCS
# 858044              Pembrokeshire  Preseli Pembrokeshire                 MCS
# 858045           Isle of Anglesey               Ynys Môn                 MCS
# 858046                    Horsham                Horsham                 MCS
#
#        MPAN Prefix  Community school category  LSOA_Code MLSOA Code
# 0             22.0    Not Community Or School  E01018840  E02003915
# 1             22.0    Not Community Or School  E01029320  E02006101
# 2             10.0    Not Community Or School  E01000255  E02000040
# 3             11.0    Not Community Or School  E01008024  E02006803
# 4             22.0    Not Community Or School  E01029214  E02006091
# ...            ...                        ...        ...        ...
# 858042        11.0    Not Community Or School  E01013536  E02002802
# 858043        17.0    Not Community Or School  S01006743  S02001277
# 858044        21.0    Not Community Or School  W01000559  W02000126
# 858045        13.0    Not Community Or School  W01000021  W02000002
# 858046        19.0    Not Community Or School  E01031640  E02006595
#
# [858047 rows x 21 columns]

# %%
lsoa_centroid
# Out:
#        LSOA_Code                  LSOA11NMW                   geometry
# 22841  E01000001        City of London 001A  POINT (-0.09628 51.51964)
# 22836  E01000002        City of London 001B  POINT (-0.09241 51.51964)
# 22838  E01000003        City of London 001C  POINT (-0.09596 51.52209)
# 22834  E01000005        City of London 001E  POINT (-0.07384 51.51303)
# 22829  E01000006  Barking and Dagenham 016A   POINT (0.08809 51.53919)
# ...          ...                        ...                        ...
# 34102  W01001954               Cardiff 006F  POINT (-3.25478 51.51628)
# 34103  W01001955               Swansea 025F  POINT (-3.94285 51.62354)
# 34100  W01001956               Swansea 023E  POINT (-4.01160 51.62276)
# 34101  W01001957               Swansea 025G  POINT (-3.94848 51.61549)
# 34108  W01001958               Swansea 025H  POINT (-3.93387 51.61579)
#
# [34753 rows x 3 columns]

# %%
lsoa_centroid["LSOA_Code"].nunique()
# Out:
# 181408

# %%
world
# Out:
#         LSOA11CD                   LSOA11NM                  LSOA11NMW  \
# 0      E01000001        City of London 001A        City of London 001A
# 1      E01000002        City of London 001B        City of London 001B
# 2      E01000003        City of London 001C        City of London 001C
# 3      E01000005        City of London 001E        City of London 001E
# 4      E01000006  Barking and Dagenham 016A  Barking and Dagenham 016A
# ...          ...                        ...                        ...
# 34748  W01001954               Cardiff 006F              Caerdydd 006F
# 34749  W01001955               Swansea 025F              Abertawe 025F
# 34750  W01001956               Swansea 023E              Abertawe 023E
# 34751  W01001957               Swansea 025G              Abertawe 025G
# 34752  W01001958               Swansea 025H              Abertawe 025H
#
#                                                 geometry
# 0      POLYGON ((-0.09729 51.52158, -0.09652 51.52027...
# 1      POLYGON ((-0.08813 51.51941, -0.08929 51.51752...
# 2      POLYGON ((-0.09679 51.52325, -0.09647 51.52282...
# 3      POLYGON ((-0.07323 51.51000, -0.07553 51.50974...
# 4      POLYGON ((0.09115 51.53909, 0.09326 51.53787, ...
# ...                                                  ...
# 34748  POLYGON ((-3.25545 51.52101, -3.25488 51.51968...
# 34749  POLYGON ((-3.94052 51.63059, -3.93912 51.62701...
# 34750  POLYGON ((-4.02463 51.63614, -4.02456 51.63573...
# 34751  POLYGON ((-3.94918 51.61754, -3.94812 51.61669...
# 34752  POLYGON ((-3.93504 51.62182, -3.93144 51.61738...
#
# [34753 rows x 4 columns]

# %%
world["LSOA11CD"].nunique()
# Out:
# 34753

# %%
list(world.columns)
# Out:
# ['LSOA11CD', 'LSOA11NM', 'LSOA11NMW', 'geometry']

# %%
world.shape
# Out:
# (34753, 4)

# %%
demand_2010.shape
# Out:
# (41730, 10)

# %%
demand_2010=demand_2010.rename(columns = {'LSOACode':'LSOA_Code'})
demand_2010
# Out:
#                LAName       LACode            MSOAName     MSOACode  \
# 0          Hartlepool    E06000001      Hartlepool 001    E02002483
# 1          Hartlepool    E06000001      Hartlepool 001    E02002483
# 2          Hartlepool    E06000001      Hartlepool 001    E02002483
# 3          Hartlepool    E06000001      Hartlepool 001    E02002483
# 4          Hartlepool    E06000001      Hartlepool 001    E02002483
# ...               ...          ...                 ...          ...
# 41725  Merthyr Tydfil    W06000024  Merthyr Tydfil 008    W02000415
# 41726  Merthyr Tydfil    W06000024  Merthyr Tydfil 008    W02000415
# 41727  Merthyr Tydfil    W06000024  Merthyr Tydfil 008    W02000415
# 41728  Merthyr Tydfil    W06000024  Merthyr Tydfil 008    W02000415
# 41729     Unallocated  Unallocated         Unallocated  Unallocated
#
#                   LSOAName    LSOA_Code  METERS           KWH  MEAN  MEDIAN
# 0          Hartlepool 001A    E01011954     962  3.061224e+06  3182    2813
# 1          Hartlepool 001B    E01011969     638  2.184541e+06  3424    3051
# 2          Hartlepool 001C    E01011970     452  1.813380e+06  4012    3480
# 3          Hartlepool 001D    E01011971     530  2.076311e+06  3918    3672
# 4          Hartlepool 001F    E01033465     746  2.620862e+06  3513    3077
# ...                    ...          ...     ...           ...   ...     ...
# 41725  Merthyr Tydfil 008C    W01001301     786  2.559067e+06  3256    2996
# 41726  Merthyr Tydfil 008D    W01001308     505  2.129738e+06  4217    3710
# 41727  Merthyr Tydfil 008E    W01001309     523  1.845027e+06  3528    3174
# 41728  Merthyr Tydfil 008F    W01001898     657  2.572098e+06  3915    3312
# 41729          Unallocated  Unallocated   48893  1.911760e+08  3910    2977
#
# [41730 rows x 10 columns]

# %%
world.nunique()
# Out:
# LSOA_Code    34753
# LSOA11NM     34753
# LSOA11NMW    34753
# geometry     34753
# dtype: int64

# %%
demand_2010["LSOACode"].nunique()
# Out:
# 41730

# %%
world.set_index("LSOA11CD", inplace = True)

# %%
demand_2010.set_index("LSOACode", inplace = True)

# %%
new_demand_2010 = demand_2010[demand_2010['LSOA_Code'].isin(world['LSOA_Code'])]
new_demand_2010.shape
# Out:
# (34753, 10)

# %%
new_demand_2010.sort_values('LSOA_Code')
new_demand_2010
# Out:
#                LAName     LACode            MSOAName   MSOACode  \
# 0          Hartlepool  E06000001      Hartlepool 001  E02002483
# 1          Hartlepool  E06000001      Hartlepool 001  E02002483
# 2          Hartlepool  E06000001      Hartlepool 001  E02002483
# 3          Hartlepool  E06000001      Hartlepool 001  E02002483
# 4          Hartlepool  E06000001      Hartlepool 001  E02002483
# ...               ...        ...                 ...        ...
# 41724  Merthyr Tydfil  W06000024  Merthyr Tydfil 008  W02000415
# 41725  Merthyr Tydfil  W06000024  Merthyr Tydfil 008  W02000415
# 41726  Merthyr Tydfil  W06000024  Merthyr Tydfil 008  W02000415
# 41727  Merthyr Tydfil  W06000024  Merthyr Tydfil 008  W02000415
# 41728  Merthyr Tydfil  W06000024  Merthyr Tydfil 008  W02000415
#
#                   LSOAName  LSOA_Code  METERS         KWH  MEAN  MEDIAN
# 0          Hartlepool 001A  E01011954     962  3061223.70  3182    2813
# 1          Hartlepool 001B  E01011969     638  2184541.40  3424    3051
# 2          Hartlepool 001C  E01011970     452  1813380.30  4012    3480
# 3          Hartlepool 001D  E01011971     530  2076311.20  3918    3672
# 4          Hartlepool 001F  E01033465     746  2620861.50  3513    3077
# ...                    ...        ...     ...         ...   ...     ...
# 41724  Merthyr Tydfil 008B  W01001300     700  2522482.60  3604    3326
# 41725  Merthyr Tydfil 008C  W01001301     786  2559066.80  3256    2996
# 41726  Merthyr Tydfil 008D  W01001308     505  2129738.20  4217    3710
# 41727  Merthyr Tydfil 008E  W01001309     523  1845026.75  3528    3174
# 41728  Merthyr Tydfil 008F  W01001898     657  2572098.50  3915    3312
#
# [34753 rows x 10 columns]

# %%
new_demand_2010['KWH'].describe()
# Out:
# count    3.475300e+04
# mean     2.914666e+06
# std      8.818661e+05
# min      1.039447e+05
# 25%      2.359169e+06
# 50%      2.698928e+06
# 75%      3.230048e+06
# max      1.496584e+07
# Name: KWH, dtype: float64

# %%
new_demand_2010['MEDIAN'].median()
# Out:
# 3329.0

# %%
world['demand_2010'] = new_demand_2010['MEAN']
world
# Out:
#         LSOA11CD                   LSOA11NM                  LSOA11NMW  \
# 0      E01000001        City of London 001A        City of London 001A
# 1      E01000002        City of London 001B        City of London 001B
# 2      E01000003        City of London 001C        City of London 001C
# 3      E01000005        City of London 001E        City of London 001E
# 4      E01000006  Barking and Dagenham 016A  Barking and Dagenham 016A
# ...          ...                        ...                        ...
# 34748  W01001954               Cardiff 006F              Caerdydd 006F
# 34749  W01001955               Swansea 025F              Abertawe 025F
# 34750  W01001956               Swansea 023E              Abertawe 023E
# 34751  W01001957               Swansea 025G              Abertawe 025G
# 34752  W01001958               Swansea 025H              Abertawe 025H
#
#                                                 geometry  demand_2010
# 0      POLYGON ((-0.09729 51.52158, -0.09652 51.52027...       3182.0
# 1      POLYGON ((-0.08813 51.51941, -0.08929 51.51752...       3424.0
# 2      POLYGON ((-0.09679 51.52325, -0.09647 51.52282...       4012.0
# 3      POLYGON ((-0.07323 51.51000, -0.07553 51.50974...       3918.0
# 4      POLYGON ((0.09115 51.53909, 0.09326 51.53787, ...       3513.0
# ...                                                  ...          ...
# 34748  POLYGON ((-3.25545 51.52101, -3.25488 51.51968...          NaN
# 34749  POLYGON ((-3.94052 51.63059, -3.93912 51.62701...          NaN
# 34750  POLYGON ((-4.02463 51.63614, -4.02456 51.63573...          NaN
# 34751  POLYGON ((-3.94918 51.61754, -3.94812 51.61669...          NaN
# 34752  POLYGON ((-3.93504 51.62182, -3.93144 51.61738...          NaN
#
# [34753 rows x 5 columns]

# %%
installations=installations.rename(columns = {'LLSOA Code':'LSOA_Code'})
installations=installations.sort_values('LSOA_Code')
installations_is_pv =  installations['Technology']=="Photovoltaic"
installations_pv = installations[installations_is_pv]
installations_pv = installations_pv[installations_pv['Tariff Description'].str.contains("<=4kW")]
installations_pv
# Out:
#        Extension (Y/N) PostCode    Technology  Installed capacity  \
# 710909               N     EC2Y  Photovoltaic               2.520
# 677499               N     EC2Y  Photovoltaic               1.960
# 688838               N     EC2Y  Photovoltaic               2.030
# 731312               N     EC2Y  Photovoltaic               3.120
# 724280               N     EC2Y  Photovoltaic               3.135
# ...                ...      ...           ...                 ...
# 265225               N      SA2  Photovoltaic               3.920
# 513795               N      SA2  Photovoltaic               3.840
# 389221               N      SA2  Photovoltaic               3.320
# 204732               N      SA1  Photovoltaic               1.880
# 471785               N      SA1  Photovoltaic               4.000
#
#         Declared net capacity     Application date Commissioning date  \
# 710909                   2.50  2016-01-14 00:00:00         2016-01-12
# 677499                   1.96  2015-10-30 00:00:00         2015-10-08
# 688838                   2.03  2015-11-26 00:00:00         2015-11-26
# 731312                   2.80  2015-12-30 00:00:00         2015-12-10
# 724280                   2.80  2016-01-14 00:00:00         2016-01-13
# ...                       ...                  ...                ...
# 265225                   3.92  2012-02-13 00:00:00         2012-02-07
# 513795                   3.84  2014-08-19 00:00:00         2014-07-24
# 389221                   3.32  2013-05-31 00:00:00         2013-05-27
# 204732                   1.88  2011-12-09 00:00:00         2011-11-23
# 471785                   4.00  2014-02-06 00:00:00         2014-01-29
#
#         MCS issue date    Export status      TariffCode  ...  \
# 710909             NaN  Export (Deemed)  PV-R/0-4/06M-3  ...
# 677499             NaN  Export (Deemed)  PV-R/0-4/06M-2  ...
# 688838             NaN  Export (Deemed)  PV-R/0-4/06M-2  ...
# 731312             NaN  Export (Deemed)  PV-R/0-4/06M-2  ...
# 724280             NaN  Export (Deemed)  PV-R/0-4/06M-3  ...
# ...                ...              ...             ...  ...
# 265225             NaN  Export (Deemed)     PV-R/0-4/02  ...
# 513795             NaN  Export (Deemed)  PV-R/0-4/05H-1  ...
# 389221             NaN  Export (Deemed)  PV-R/0-4/04H-1  ...
# 204732             NaN  Export (Deemed)     PV-R/0-4/02  ...
# 471785             NaN  Export (Deemed)  PV-R/0-4/04H-4  ...
#
#        Installation Type Installation Country Government Office Region  \
# 710909          Domestic              England                   London
# 677499          Domestic              England                   London
# 688838          Domestic              England                   London
# 731312          Domestic              England                   London
# 724280          Domestic              England                   London
# ...                  ...                  ...                      ...
# 265225          Domestic                Wales                    Wales
# 513795          Domestic                Wales                    Wales
# 389221          Domestic                Wales                    Wales
# 204732          Domestic                Wales                    Wales
# 471785          Domestic                Wales                    Wales
#
#        Local Authority                      Constituency Accreditation Route  \
# 710909  City of London  Cities of London and Westminster                 MCS
# 677499  City of London  Cities of London and Westminster                 MCS
# 688838  City of London  Cities of London and Westminster                 MCS
# 731312  City of London  Cities of London and Westminster                 MCS
# 724280  City of London  Cities of London and Westminster                 MCS
# ...                ...                               ...                 ...
# 265225         Swansea                      Swansea West                 MCS
# 513795         Swansea                      Swansea West                 MCS
# 389221         Swansea                      Swansea West                 MCS
# 204732         Swansea                      Swansea West                 MCS
# 471785         Swansea                      Swansea West                 MCS
#
#        MPAN Prefix  Community school category  LSOA_Code MLSOA Code
# 710909        16.0    Not Community Or School  E01000002  E02000001
# 677499        16.0    Not Community Or School  E01000002  E02000001
# 688838        16.0    Not Community Or School  E01000002  E02000001
# 731312        10.0    Not Community Or School  E01000002  E02000001
# 724280        10.0    Not Community Or School  E01000002  E02000001
# ...            ...                        ...        ...        ...
# 265225        21.0    Not Community Or School  W01001956  W02000190
# 513795        21.0    Not Community Or School  W01001956  W02000190
# 389221        21.0    Not Community Or School  W01001956  W02000190
# 204732        21.0    Not Community Or School  W01001957  W02000192
# 471785        21.0    Not Community Or School  W01001958  W02000192
#
# [788516 rows x 21 columns]

# %%
list(installations_pv.columns)
# Out:
# ['Extension (Y/N)',
#  'PostCode',
#  'Technology',
#  'Installed capacity',
#  'Declared net capacity',
#  'Application date',
#  'Commissioning date',
#  'MCS issue date',
#  'Export status',
#  'TariffCode',
#  'Tariff Description',
#  'Installation Type',
#  'Installation Country',
#  'Government Office Region',
#  'Local Authority',
#  'Constituency',
#  'Accreditation Route',
#  'MPAN Prefix',
#  'Community school category',
#  'LSOA_Code',
#  'MLSOA Code']

# %%
installations_pv["Technology"].nunique()
# Out:
# 1

# %%
installations_pv_agg = installations_pv.groupby(['LSOA_Code'])['Installed capacity'].count()
installations_pv_agg = pd.DataFrame(data=installations_pv_agg)
installations_pv_agg
# Out:
#            Installed capacity
# LSOA_Code
# E01000002                   8
# E01000006                   5
# E01000008                   1
# E01000011                   1
# E01000012                   2
# ...                       ...
# W01001953                   9
# W01001954                  18
# W01001956                  13
# W01001957                   1
# W01001958                   1
#
# [39565 rows x 1 columns]

# %%
installations_pv_agg['Installed capacity'].describe()
# Out:
# count    39565.000000
# mean        19.929635
# std         21.237081
# min          1.000000
# 25%          6.000000
# 50%         14.000000
# 75%         26.000000
# max        394.000000
# Name: Installed capacity, dtype: float64

# %%
installations_pv_agg['Installed capacity'].median()
# Out:
# 14.0

# %%
installations_pv_agg['Installed capacity'].sum()
# Out:
# 788516

# %%
test = installations_pv_agg.join(world.set_index('LSOA_Code'))
test
# Out:
#            Installed capacity                   LSOA11NM  \
# LSOA_Code
# E01000002               22.69        City of London 001B
# E01000003               21.00        City of London 001C
# E01000005               24.65        City of London 001E
# E01000006               11.63  Barking and Dagenham 016A
# E01000008              102.59  Barking and Dagenham 015B
# ...                       ...                        ...
# W01001954               66.45               Cardiff 006F
# W01001955               29.90               Swansea 025F
# W01001956               53.99               Swansea 023E
# W01001957                1.88               Swansea 025G
# W01001958               52.50               Swansea 025H
#
#                            LSOA11NMW  \
# LSOA_Code
# E01000002        City of London 001B
# E01000003        City of London 001C
# E01000005        City of London 001E
# E01000006  Barking and Dagenham 016A
# E01000008  Barking and Dagenham 015B
# ...                              ...
# W01001954              Caerdydd 006F
# W01001955              Abertawe 025F
# W01001956              Abertawe 023E
# W01001957              Abertawe 025G
# W01001958              Abertawe 025H
#
#                                                     geometry
# LSOA_Code
# E01000002  POLYGON ((-0.08813 51.51941, -0.08929 51.51752...
# E01000003  POLYGON ((-0.09679 51.52325, -0.09647 51.52282...
# E01000005  POLYGON ((-0.07323 51.51000, -0.07553 51.50974...
# E01000006  POLYGON ((0.09115 51.53909, 0.09326 51.53787, ...
# E01000008  MULTIPOLYGON (((0.07135 51.54169, 0.07229 51.5...
# ...                                                      ...
# W01001954  POLYGON ((-3.25545 51.52101, -3.25488 51.51968...
# W01001955  POLYGON ((-3.94052 51.63059, -3.93912 51.62701...
# W01001956  POLYGON ((-4.02463 51.63614, -4.02456 51.63573...
# W01001957  POLYGON ((-3.94918 51.61754, -3.94812 51.61669...
# W01001958  POLYGON ((-3.93504 51.62182, -3.93144 51.61738...
#
# [40042 rows x 4 columns]

# %%
world
# Out:
#        LSOA_Code                   LSOA11NM                  LSOA11NMW  \
# 0      E01000001        City of London 001A        City of London 001A
# 1      E01000002        City of London 001B        City of London 001B
# 2      E01000003        City of London 001C        City of London 001C
# 3      E01000005        City of London 001E        City of London 001E
# 4      E01000006  Barking and Dagenham 016A  Barking and Dagenham 016A
# ...          ...                        ...                        ...
# 34748  W01001954               Cardiff 006F              Caerdydd 006F
# 34749  W01001955               Swansea 025F              Abertawe 025F
# 34750  W01001956               Swansea 023E              Abertawe 023E
# 34751  W01001957               Swansea 025G              Abertawe 025G
# 34752  W01001958               Swansea 025H              Abertawe 025H
#
#                                                 geometry
# 0      POLYGON ((-0.09729 51.52158, -0.09652 51.52027...
# 1      POLYGON ((-0.08813 51.51941, -0.08929 51.51752...
# 2      POLYGON ((-0.09679 51.52325, -0.09647 51.52282...
# 3      POLYGON ((-0.07323 51.51000, -0.07553 51.50974...
# 4      POLYGON ((0.09115 51.53909, 0.09326 51.53787, ...
# ...                                                  ...
# 34748  POLYGON ((-3.25545 51.52101, -3.25488 51.51968...
# 34749  POLYGON ((-3.94052 51.63059, -3.93912 51.62701...
# 34750  POLYGON ((-4.02463 51.63614, -4.02456 51.63573...
# 34751  POLYGON ((-3.94918 51.61754, -3.94812 51.61669...
# 34752  POLYGON ((-3.93504 51.62182, -3.93144 51.61738...
#
# [34753 rows x 4 columns]

# %%
test2 = pd.DataFrame()
test2 = pd.merge(installations_pv_agg, world, how='right', on='LSOA_Code')
test2['Installed capacity'] = test2['Installed capacity'].fillna(0)

test2
# Out:
#        LSOA_Code  Installed capacity                   LSOA11NM  \
# 0      E01000002                 8.0        City of London 001B
# 1      E01000006                 5.0  Barking and Dagenham 016A
# 2      E01000008                 1.0  Barking and Dagenham 015B
# 3      E01000011                 1.0  Barking and Dagenham 016C
# 4      E01000012                 2.0  Barking and Dagenham 015D
# ...          ...                 ...                        ...
# 34748  W01001943                 0.0               Cardiff 048B
# 34749  W01001945                 0.0               Cardiff 048D
# 34750  W01001950                 0.0               Cardiff 049D
# 34751  W01001951                 0.0               Cardiff 049E
# 34752  W01001955                 0.0               Swansea 025F
#
#                        LSOA11NMW  \
# 0            City of London 001B
# 1      Barking and Dagenham 016A
# 2      Barking and Dagenham 015B
# 3      Barking and Dagenham 016C
# 4      Barking and Dagenham 015D
# ...                          ...
# 34748              Caerdydd 048B
# 34749              Caerdydd 048D
# 34750              Caerdydd 049D
# 34751              Caerdydd 049E
# 34752              Abertawe 025F
#
#                                                 geometry
# 0      POLYGON ((-0.08813 51.51941, -0.08929 51.51752...
# 1      POLYGON ((0.09115 51.53909, 0.09326 51.53787, ...
# 2      MULTIPOLYGON (((0.07135 51.54169, 0.07229 51.5...
# 3      POLYGON ((0.08272 51.54350, 0.08475 51.54249, ...
# 4      POLYGON ((0.07864 51.54357, 0.07864 51.54328, ...
# ...                                                  ...
# 34748  POLYGON ((-3.16549 51.47186, -3.16499 51.47121...
# 34749  POLYGON ((-3.17892 51.45107, -3.17731 51.44971...
# 34750  POLYGON ((-3.17091 51.46776, -3.17016 51.46688...
# 34751  POLYGON ((-3.16151 51.47686, -3.15972 51.47458...
# 34752  POLYGON ((-3.94052 51.63059, -3.93912 51.62701...
#
# [34753 rows x 5 columns]

# %%
test3 = pd.merge(demand_2018, test2, how='right', on='LSOA_Code')
test3['Install_%'] = 100 * test2['Installed capacity']/test3['METERS']
test3
test3['Install_%'].describe()
# Out:
# count    34753.000000
# mean         3.002703
# std          3.246274
# min          0.000000
# 25%          0.907716
# 50%          2.058824
# 75%          3.947368
# max         49.090909
# Name: Install_%, dtype: float64

# %%
test2['Installed capacity'].std()
# Out:
# 21.866066244665884

# %%
list(test2.columns)
# Out:
# ['LSOA_Code', 'Installed capacity', 'LSOA11NM', 'LSOA11NMW', 'geometry']

# %%
test2
# Out:
#        LSOA_Code  Installed capacity                   LSOA11NM  \
# 0      E01000002                 8.0        City of London 001B
# 1      E01000006                 5.0  Barking and Dagenham 016A
# 2      E01000008                 1.0  Barking and Dagenham 015B
# 3      E01000011                 1.0  Barking and Dagenham 016C
# 4      E01000012                 2.0  Barking and Dagenham 015D
# ...          ...                 ...                        ...
# 34748  W01001943                 NaN               Cardiff 048B
# 34749  W01001945                 NaN               Cardiff 048D
# 34750  W01001950                 NaN               Cardiff 049D
# 34751  W01001951                 NaN               Cardiff 049E
# 34752  W01001955                 NaN               Swansea 025F
#
#                        LSOA11NMW  \
# 0            City of London 001B
# 1      Barking and Dagenham 016A
# 2      Barking and Dagenham 015B
# 3      Barking and Dagenham 016C
# 4      Barking and Dagenham 015D
# ...                          ...
# 34748              Caerdydd 048B
# 34749              Caerdydd 048D
# 34750              Caerdydd 049D
# 34751              Caerdydd 049E
# 34752              Abertawe 025F
#
#                                                 geometry
# 0      POLYGON ((-0.08813 51.51941, -0.08929 51.51752...
# 1      POLYGON ((0.09115 51.53909, 0.09326 51.53787, ...
# 2      MULTIPOLYGON (((0.07135 51.54169, 0.07229 51.5...
# 3      POLYGON ((0.08272 51.54350, 0.08475 51.54249, ...
# 4      POLYGON ((0.07864 51.54357, 0.07864 51.54328, ...
# ...                                                  ...
# 34748  POLYGON ((-3.16549 51.47186, -3.16499 51.47121...
# 34749  POLYGON ((-3.17892 51.45107, -3.17731 51.44971...
# 34750  POLYGON ((-3.17091 51.46776, -3.17016 51.46688...
# 34751  POLYGON ((-3.16151 51.47686, -3.15972 51.47458...
# 34752  POLYGON ((-3.94052 51.63059, -3.93912 51.62701...
#
# [34753 rows x 5 columns]

# %%
world['Installed capacity'] = test2['Installed capacity']
world['Installed capacity'] = world['Installed capacity'] + 0.01
world['Installed capacity'] = np.log(world['Installed capacity'])
world
# Out:
#         LSOA11CD                   LSOA11NM                  LSOA11NMW  \
# 0      E01000001        City of London 001A        City of London 001A
# 1      E01000002        City of London 001B        City of London 001B
# 2      E01000003        City of London 001C        City of London 001C
# 3      E01000005        City of London 001E        City of London 001E
# 4      E01000006  Barking and Dagenham 016A  Barking and Dagenham 016A
# ...          ...                        ...                        ...
# 34748  W01001954               Cardiff 006F              Caerdydd 006F
# 34749  W01001955               Swansea 025F              Abertawe 025F
# 34750  W01001956               Swansea 023E              Abertawe 023E
# 34751  W01001957               Swansea 025G              Abertawe 025G
# 34752  W01001958               Swansea 025H              Abertawe 025H
#
#                                                 geometry  Installed capacity
# 0      POLYGON ((-0.09729 51.52158, -0.09652 51.52027...            2.080691
# 1      POLYGON ((-0.08813 51.51941, -0.08929 51.51752...            1.611436
# 2      POLYGON ((-0.09679 51.52325, -0.09647 51.52282...            0.009950
# 3      POLYGON ((-0.07323 51.51000, -0.07553 51.50974...            0.009950
# 4      POLYGON ((0.09115 51.53909, 0.09326 51.53787, ...            0.698135
# ...                                                  ...                 ...
# 34748  POLYGON ((-3.25545 51.52101, -3.25488 51.51968...                 NaN
# 34749  POLYGON ((-3.94052 51.63059, -3.93912 51.62701...                 NaN
# 34750  POLYGON ((-4.02463 51.63614, -4.02456 51.63573...                 NaN
# 34751  POLYGON ((-3.94918 51.61754, -3.94812 51.61669...                 NaN
# 34752  POLYGON ((-3.93504 51.62182, -3.93144 51.61738...                 NaN
#
# [34753 rows x 5 columns]

# %%
Merge_DF_2['Install_%'].describe
# Out:
# count    74318.000000
# mean         1.404791
# std          2.678606
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.869660
# max         49.109091
# Name: Install_%, dtype: float64

# %%
del [Merge_DF,Merge_DF_2,my_world]
#del(Merge_DF)
#del(Merge_DF_2)
gc.collect()
Merge_DF=pd.DataFrame()
Merge_DF_2=pd.DataFrame()
my_world=pd.DataFrame()

# %%
list(Merge_DF.columns)
# Out:
#                      LAName     LACode                  MSOAName   MSOACode  \
# 0            City of London  E09000001        City of London 001  E02000001
# 1            City of London  E09000001        City of London 001  E02000001
# 2            City of London  E09000001        City of London 001  E02000001
# 3            City of London  E09000001        City of London 001  E02000001
# 4      Barking and Dagenham  E09000002  Barking and Dagenham 016  E02000017
# ...                     ...        ...                       ...        ...
# 34748               Cardiff  W06000015               Cardiff 006  W02000372
# 34749               Swansea  W06000011               Swansea 025  W02000192
# 34750               Swansea  W06000011               Swansea 023  W02000190
# 34751               Swansea  W06000011               Swansea 025  W02000192
# 34752               Swansea  W06000011               Swansea 025  W02000192
#
#                         LSOAName  LSOA_Code  METERS          KWH         MEAN  \
# 0            City of London 001A  E01000001    1056  4397418.106  4164.221691
# 1            City of London 001B  E01000002    1155  4391815.800  3802.437922
# 2            City of London 001C  E01000003    1182  3122919.400  2642.063790
# 3            City of London 001E  E01000005     563  1642298.833  2917.049438
# 4      Barking and Dagenham 016A  E01000006     529  2211867.367  4181.223756
# ...                          ...        ...     ...          ...          ...
# 34748               Cardiff 006F  W01001954     673  2683554.100  3987.450372
# 34749               Swansea 025F  W01001955    1382  3671856.500  2656.914978
# 34750               Swansea 023E  W01001956     866  2620889.100  3026.430831
# 34751               Swansea 025G  W01001957     501  1295671.500  2586.170659
# 34752               Swansea 025H  W01001958     979  3259396.600  3329.312155
#
#         MEDIAN  Installed capacity                   LSOA11NM  \
# 0      3535.25                 NaN        City of London 001A
# 1      2996.40                 8.0        City of London 001B
# 2      1917.70                 NaN        City of London 001C
# 3      2071.70                 NaN        City of London 001E
# 4      3693.60                 5.0  Barking and Dagenham 016A
# ...        ...                 ...                        ...
# 34748  3471.00                18.0               Cardiff 006F
# 34749  1853.60                 NaN               Swansea 025F
# 34750  2431.95                13.0               Swansea 023E
# 34751  1972.20                 1.0               Swansea 025G
# 34752  2151.20                 1.0               Swansea 025H
#
#                        LSOA11NMW  \
# 0            City of London 001A
# 1            City of London 001B
# 2            City of London 001C
# 3            City of London 001E
# 4      Barking and Dagenham 016A
# ...                          ...
# 34748              Caerdydd 006F
# 34749              Abertawe 025F
# 34750              Abertawe 023E
# 34751              Abertawe 025G
# 34752              Abertawe 025H
#
#                                                 geometry  Install_%
# 0      POLYGON ((-0.09729 51.52158, -0.09652 51.52027...   0.757576
# 1      POLYGON ((-0.08813 51.51941, -0.08929 51.51752...   0.432900
# 2      POLYGON ((-0.09679 51.52325, -0.09647 51.52282...   0.084602
# 3      POLYGON ((-0.07323 51.51000, -0.07553 51.50974...   0.177620
# 4      POLYGON ((0.09115 51.53909, 0.09326 51.53787, ...   0.378072
# ...                                                  ...        ...
# 34748  POLYGON ((-3.25545 51.52101, -3.25488 51.51968...   0.000000
# 34749  POLYGON ((-3.94052 51.63059, -3.93912 51.62701...   0.000000
# 34750  POLYGON ((-4.02463 51.63614, -4.02456 51.63573...   0.000000
# 34751  POLYGON ((-3.94918 51.61754, -3.94812 51.61669...   0.000000
# 34752  POLYGON ((-3.93504 51.62182, -3.93144 51.61738...   0.000000
#
# [34753 rows x 15 columns]

# %%
list(Merge_DF_2.columns)
# Out:
# ['LAName',
#  'LACode',
#  'MSOAName',
#  'MSOACode',
#  'LSOAName',
#  'LSOA_Code',
#  'METERS',
#  'KWH',
#  'MEAN',
#  'MEDIAN',
#  'Installed capacity',
#  'LSOA11NM',
#  'LSOA11NMW',
#  'geometry',
#  'Install_%']

# %%
Merge_DF
# Out:
#        LSOA_Code  Installed capacity_x                   LSOA11NM  \
# 0      E01000002                   8.0        City of London 001B
# 1      E01000006                   5.0  Barking and Dagenham 016A
# 2      E01000008                   1.0  Barking and Dagenham 015B
# 3      E01000011                   1.0  Barking and Dagenham 016C
# 4      E01000012                   2.0  Barking and Dagenham 015D
# ...          ...                   ...                        ...
# 34748  W01001943                   NaN               Cardiff 048B
# 34749  W01001945                   NaN               Cardiff 048D
# 34750  W01001950                   NaN               Cardiff 049D
# 34751  W01001951                   NaN               Cardiff 049E
# 34752  W01001955                   NaN               Swansea 025F
#
#                        LSOA11NMW  \
# 0            City of London 001B
# 1      Barking and Dagenham 016A
# 2      Barking and Dagenham 015B
# 3      Barking and Dagenham 016C
# 4      Barking and Dagenham 015D
# ...                          ...
# 34748              Caerdydd 048B
# 34749              Caerdydd 048D
# 34750              Caerdydd 049D
# 34751              Caerdydd 049E
# 34752              Abertawe 025F
#
#                                                 geometry  Installed capacity_y
# 0      POLYGON ((-0.08813 51.51941, -0.08929 51.51752...                  8.01
# 1      POLYGON ((0.09115 51.53909, 0.09326 51.53787, ...                  5.01
# 2      MULTIPOLYGON (((0.07135 51.54169, 0.07229 51.5...                  1.01
# 3      POLYGON ((0.08272 51.54350, 0.08475 51.54249, ...                  1.01
# 4      POLYGON ((0.07864 51.54357, 0.07864 51.54328, ...                  2.01
# ...                                                  ...                   ...
# 34748  POLYGON ((-3.16549 51.47186, -3.16499 51.47121...                   NaN
# 34749  POLYGON ((-3.17892 51.45107, -3.17731 51.44971...                   NaN
# 34750  POLYGON ((-3.17091 51.46776, -3.17016 51.46688...                   NaN
# 34751  POLYGON ((-3.16151 51.47686, -3.15972 51.47458...                   NaN
# 34752  POLYGON ((-3.94052 51.63059, -3.93912 51.62701...                   NaN
#
# [34753 rows x 6 columns]

# %%
my_world
# Out:
#       LSOA_Code       LSOA11NMW                   geometry  Installed capacity
# 6154  E01008066  Sheffield 028B  POINT (-1.49726 53.38606)                 8.0
# 6155  E01008067  Sheffield 030D  POINT (-1.49505 53.38478)                 5.0
# 6156  E01008064  Sheffield 028A  POINT (-1.50544 53.38546)                 6.0
# 6157  E01008062  Sheffield 013E  POINT (-1.45050 53.42157)                17.0
# 6158  E01008063  Sheffield 011B  POINT (-1.46085 53.42166)                 8.0
# ...         ...             ...                        ...                 ...
# 9382  E01007990  Sheffield 021A  POINT (-1.52305 53.40601)                23.0
# 9413  E01008156  Sheffield 024E  POINT (-1.51082 53.39421)                 3.0
# 9449  E01008039  Sheffield 065F  POINT (-1.34695 53.33792)                11.0
# 9459  E01008098  Sheffield 048A  POINT (-1.43355 53.36089)                 3.0
# 9470  E01008102  Sheffield 048C  POINT (-1.43687 53.35998)                23.0
#
# [345 rows x 4 columns]

# %%
J_installations_loc = "/Users/josemawyin/Library/Mobile Documents/com~apple~CloudDocs/Data Science Masters /698/Data/Jamie_PV_capacity_by_GSP_and_LLSOA/capacity_by_llsoa_and_gsp_20200617T165804/20200617T165804_capacity_by_llsoa_and_month.csv"
J_installations = pd.read_csv(J_installations_loc)
####Lower Layer Super Output Area (2011) to Clinical Commissioning Group to Local Authority District (April 2019) Lookup in England
lsoa_to_county_loc = "/Users/josemawyin/Library/Mobile Documents/com~apple~CloudDocs/Data Science Masters /698/Data/Lower_Layer_Super_Output_Area_(2011)_to_Clinical_Commissioning_Group_to_Local_Authority_District_(April_2019)_Lookup_in_England.csv"
lsoa_to_county = pd.read_csv(lsoa_to_county_loc)
lsoa_to_county=lsoa_to_county.rename(columns = {'LSOA11CD':'LSOA_Code'})
lsoa_to_county=lsoa_to_county.sort_values('LSOA_Code')
###Local Authority District to County (April 2019) Lookup in England
la_to_county_loc = "/Users/josemawyin/Library/Mobile Documents/com~apple~CloudDocs/Data Science Masters /698/Data/Local_Authority_District_to_County_(April_2019)_Lookup_in_England.csv"
la_to_county = pd.read_csv(la_to_county_loc)
la_to_county
# Out:
#      FID    LAD19CD                LAD19NM    CTY19CD     CTY19NM
# 0      1  E07000120               Hyndburn  E10000017  Lancashire
# 1      2  E07000121              Lancaster  E10000017  Lancashire
# 2      3  E07000122                 Pendle  E10000017  Lancashire
# 3      4  E07000123                Preston  E10000017  Lancashire
# 4      5  E07000124          Ribble Valley  E10000017  Lancashire
# ..   ...        ...                    ...        ...         ...
# 256  257  E07000115  Tonbridge and Malling  E10000016        Kent
# 257  258  E07000116        Tunbridge Wells  E10000016        Kent
# 258  259  E07000117                Burnley  E10000017  Lancashire
# 259  260  E07000118                Chorley  E10000017  Lancashire
# 260  261  E07000119                  Fylde  E10000017  Lancashire
#
# [261 rows x 5 columns]

# %%
### Count unique values in column
la_to_county["CTY19NM"].nunique()
### List unique values in column
la_to_county.CTY19NM.unique()
# Out:
# array(['Lancashire', 'Leicestershire', 'Lincolnshire', 'Norfolk',
#        'Northamptonshire', 'North Yorkshire', 'Nottinghamshire',
#        'Oxfordshire', 'Inner London', 'Outer London',
#        'Greater Manchester', 'Merseyside', 'South Yorkshire',
#        'Tyne and Wear', 'Essex', 'West Midlands', 'Somerset',
#        'Staffordshire', 'West Yorkshire', 'Buckinghamshire',
#        'Cambridgeshire', 'Cumbria', 'Derbyshire', 'Devon', 'East Sussex',
#        'Gloucestershire', 'Suffolk', 'Hampshire', 'Surrey',
#        'Warwickshire', 'West Sussex', 'Worcestershire', 'Hertfordshire',
#        'Kent'], dtype=object)

# %%
lsoa_to_county.LAD19NM.nunique()
lsoa_to_county
# Out:
#          FID  LSOA_Code                   LSOA11NM    CCG19CD CCG19CDH  \
# 28104  28105  E01000001        City of London 001A  E38000035      07T
# 28110  28111  E01000002        City of London 001B  E38000035      07T
# 28119  28120  E01000003        City of London 001C  E38000035      07T
# 28126  28127  E01000005        City of London 001E  E38000035      07T
# 28144  28145  E01000006  Barking and Dagenham 016A  E38000004      07L
# ...      ...        ...                        ...        ...      ...
# 22802  22803  E01033764             Liverpool 022E  E38000101      99A
# 22806  22807  E01033765             Liverpool 061D  E38000101      99A
# 22808  22809  E01033766             Liverpool 042G  E38000101      99A
# 22810  22811  E01033767             Liverpool 050J  E38000101      99A
# 22812  22813  E01033768             Liverpool 037F  E38000101      99A
#
#                             CCG19NM    LAD19CD               LAD19NM
# 28104      NHS City and Hackney CCG  E09000001        City of London
# 28110      NHS City and Hackney CCG  E09000001        City of London
# 28119      NHS City and Hackney CCG  E09000001        City of London
# 28126      NHS City and Hackney CCG  E09000001        City of London
# 28144  NHS Barking and Dagenham CCG  E09000002  Barking and Dagenham
# ...                             ...        ...                   ...
# 22802             NHS Liverpool CCG  E08000012             Liverpool
# 22806             NHS Liverpool CCG  E08000012             Liverpool
# 22808             NHS Liverpool CCG  E08000012             Liverpool
# 22810             NHS Liverpool CCG  E08000012             Liverpool
# 22812             NHS Liverpool CCG  E08000012             Liverpool
#
# [32844 rows x 8 columns]

# %% [markdown]
# Choosing Colormaps in Matplotlib
# https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
#
# Lower Layer Super Output Area (2011) to Clinical Commissioning Group to Local Authority District (April 2019) Lookup in England
# https://geoportal.statistics.gov.uk/datasets/lower-layer-super-output-area-2011-to-clinical-commissioning-group-to-local-authority-district-april-2019-lookup-in-england/data
#
#
# Local Authority District to County (April 2019) Lookup in England
# https://geoportal.statistics.gov.uk/datasets/local-authority-district-to-county-april-2019-lookup-in-england/data
